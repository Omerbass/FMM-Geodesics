# %%
from irregular_grids import BoundedGrid
from metrics import AntiFerro
import fmm_metric_geodesic_paths as fmgp
import numpy as np
import matplotlib.pyplot as plt
import holoviews as hv
hv.extension("bokeh")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d4847aff-904a-4150-9b7f-c1497891c150'>
#   <div id="a84cde6b-631e-4a25-a31f-385e04b2d02b" data-root-id="d4847aff-904a-4150-9b7f-c1497891c150" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
result = np.load("data/antiferro_geodesic_paths_T0=0.400_h0=1.150.npz", allow_pickle=True)

# %%
result["grid"][()].point_to_idx((0.98, 0.22))
# Out:
# np.int64(17898)

# %%
antiferro = AntiFerro()
geopaths = fmgp.FMMGeodesicPaths(antiferro.metric, antiferro.inv_metric)

pth = geopaths.gradient_descent_to_origin(result["grid"][()], result["deluanay"][()], result["distances"], 17898, step_size=0.002, tol=1e-1)

# %%
hv.Scatter({"x": result["positions"][:,0], "y": result["positions"][:,1], "c": result["distances"]}, kdims = "x", 
vdims=["y","c"]).opts(size=10, color="c") *\
hv.Curve(pth).opts(color="red")
# Out:
# :Overlay
#    .Scatter.I :Scatter   [x]   (y,c)
#    .Curve.I   :Curve   [x]   (y)

# %%
with open("tmp.txt", "w") as f:
    for p in pth:
        f.write(f"[{p[0]}, {p[1]}],\n")

# %%
b = np.vstack((pth[pth[:,1] < 1.01, :],(0.4, 1.15),))
antiferro.dist(b)
# Out:
# np.float64(0.9653402732283588)

# %%
antiferro.dist(pth[pth[:,1] < 1.01, :]), antiferro.dist(np.linspace((0.98, 0.22), pth[pth[:,1] < 1.01, :][-1], 1000))
# Out:
# (np.float64(0.7985932722262692), np.float64(0.7060112714459561))

# %%
antiferro.dist(np.linspace((0.98, 0.22), (0.4,1.15), 1000))
# Out:
# np.float64(0.8559650842781346)
